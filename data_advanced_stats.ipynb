# %%
## Import relevant Packages
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
## Define the function and get input from the user
def get_NBA_stats():
    year = input("Which NBA season are you interested in?: ")
    player = input("For which player do you want to get stats?: ")

# %%
## Scrape and save data
year = input("Which NBA season are you interested in?: ")
url = 'https://www.basketball-reference.com/leagues/NBA_2021_advanced.html'.format(year)
   
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html,'html.parser')
# Out:
# Which NBA season are you interested in?:  2020-21

# %%
table=soup.find_all(class_="full_table")
    
""" Extracting List of column names"""
head=soup.find(class_="thead")
column_names_raw=[head.text for item in head][0]
column_names_polished=column_names_raw.replace("\n",",").split(",")[2:-1]
print(column_names_polished)
['Player',
 'Pos',
 'Age',
 'Tm',
 'G',
 'MP',
 'PER',
 'TS%',
 '3PAr',
 'FTr',
 'ORB%',
 'DRB%',
 'TRB%',
 'AST%',
 'STL%',
 'BLK%',
 'TOV%',
 'USG%',
 'OWS',
 'DWS',
 'WS',
 'WS/48',
 'OBPM',
 'DBPM',
 'BPM',
 'VORP'
]
# Out:
# ['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', '\xa0', 'OWS', 'DWS', 'WS', 'WS/48', '\xa0', 'OBPM', 'DBPM', 'BPM', 'VORP']
# ['Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'MP',
#  'PER',
#  'TS%',
#  '3PAr',
#  'FTr',
#  'ORB%',
#  'DRB%',
#  'TRB%',
#  'AST%',
#  'STL%',
#  'BLK%',
#  'TOV%',
#  'USG%',
#  'OWS',
#  'DWS',
#  'WS',
#  'WS/48',
#  'OBPM',
#  'DBPM',
#  'BPM',
#  'VORP']

# %%
"""Extracting full list of player_data"""
players=[]
    
for i in range(len(table)):
        
        player_=[]
        
        for td in table[i].find_all("td"):
            player_.append(td.text)
    
        players.append(player_)
df=pd.DataFrame(players, columns=column_names_polished).set_index("Player")
#cleaning the player's name from occasional special characters
df.index=df.index.str.replace('*', '')
# Out:
# C:\Users\Amand\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df
# Out:
#                      Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr  ORB%  \
# Player
# Precious Achiuwa      PF  21  MIA  61   737  14.2  .550  .004  .482  11.5
# Jaylen Adams          PG  24  MIL   7    18  -6.5  .125  .250  .000   0.0
# Steven Adams           C  27  NOP  58  1605  15.1  .596  .010  .438  14.4
# Bam Adebayo            C  23  MIA  64  2143  22.7  .626  .010  .443   7.7
# LaMarcus Aldridge      C  35  TOT  26   674  15.7  .556  .270  .159   3.0
# ...                  ...  ..  ...  ..   ...   ...   ...   ...   ...   ...
# Delon Wright       SG-PG  28  TOT  63  1748  16.3  .562  .332  .243   4.1
# Thaddeus Young        PF  32  CHI  68  1652  20.3  .578  .068  .171  11.4
# Trae Young            PG  22  ATL  63  2125  23.0  .589  .357  .491   2.0
# Cody Zeller            C  28  CHO  48  1005  18.2  .599  .086  .367  12.6
# Ivica Zubac            C  23  LAC  72  1609  19.1  .693  .010  .434  13.6
#
#                    ...      OWS  DWS    WS   WS/48      OBPM  DBPM    BPM  \
# Player             ...
# Precious Achiuwa   ...      0.3  1.0   1.3    .085      -3.6  -0.5   -4.1
# Jaylen Adams       ...     -0.1  0.0  -0.1  -0.252     -15.1  -4.6  -19.8
# Steven Adams       ...      2.3  1.7   4.0    .119      -0.4   0.1   -0.3
# Bam Adebayo        ...      5.6  3.2   8.8    .197       2.9   2.0    4.9
# LaMarcus Aldridge  ...      0.5  0.6   1.1    .080      -0.2  -0.2   -0.3
# ...                ... ..   ...  ...   ...     ... ..    ...   ...    ...
# Delon Wright       ...      2.5  1.8   4.3    .117       0.6   1.5    2.2
# Thaddeus Young     ...      2.8  2.2   5.1    .147       1.9   1.4    3.3
# Trae Young         ...      5.9  1.3   7.2    .163       5.3  -1.7    3.7
# Cody Zeller        ...      2.1  1.1   3.3    .156      -0.2  -0.2   -0.5
# Ivica Zubac        ...      4.8  2.1   6.9    .206       0.6   0.4    1.0
#
#                    VORP
# Player
# Precious Achiuwa   -0.4
# Jaylen Adams       -0.1
# Steven Adams        0.7
# Bam Adebayo         3.7
# LaMarcus Aldridge   0.3
# ...                 ...
# Delon Wright        1.8
# Thaddeus Young      2.2
# Trae Young          3.0
# Cody Zeller         0.4
# Ivica Zubac         1.2
#
# [540 rows x 27 columns]

# %%
df.to_csv('advanced_stats.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 540 entries, Precious Achiuwa to Ivica Zubac
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pos     540 non-null    object
#  1   Age     540 non-null    object
#  2   Tm      540 non-null    object
#  3   G       540 non-null    object
#  4   MP      540 non-null    object
#  5   PER     540 non-null    object
#  6   TS%     540 non-null    object
#  7   3PAr    540 non-null    object
#  8   FTr     540 non-null    object
#  9   ORB%    540 non-null    object
#  10  DRB%    540 non-null    object
#  11  TRB%    540 non-null    object
#  12  AST%    540 non-null    object
#  13  STL%    540 non-null    object
#  14  BLK%    540 non-null    object
#  15  TOV%    540 non-null    object
#  16  USG%    540 non-null    object
#  17          540 non-null    object
#  18  OWS     540 non-null    object
#  19  DWS     540 non-null    object
#  20  WS      540 non-null    object
#  21  WS/48   540 non-null    object
#  22          540 non-null    object
#  23  OBPM    540 non-null    object
#  24  DBPM    540 non-null    object
#  25  BPM     540 non-null    object
#  26  VORP    540 non-null    object
# dtypes: object(27)
# memory usage: 118.1+ KB

# %%
df.columns= df.columns.str.lower()
df.columns
# Out:
# Index(['pos', 'age', 'tm', 'g', 'mp', 'per', 'ts%', '3par', 'ftr', 'orb%',
#        'drb%', 'trb%', 'ast%', 'stl%', 'blk%', 'tov%', 'usg%', ' ', 'ows',
#        'dws', 'ws', 'ws/48', ' ', 'obpm', 'dbpm', 'bpm', 'vorp'],
#       dtype='object')

# %%
df = df.rename(columns = {'ts%': 'ts_percent', 'orb%': 'orb_percent', 'drb%': 'drb_percent', 'trb%': 'trb_percent', 'ast%': 'ast_percent', 'stl%': 'stl_percent', 'blk%': 'blk_percent', 'tov%': 'tov_percent', 'usg%': 'usg_percent', 'ws/48': 'ws_per_48', '3par': 'threepoint_attr'})
df.head()
# Out:
#                   pos age   tm   g    mp   per ts_percent threepoint_attr  \
# Player
# Precious Achiuwa   PF  21  MIA  61   737  14.2       .550            .004
# Jaylen Adams       PG  24  MIL   7    18  -6.5       .125            .250
# Steven Adams        C  27  NOP  58  1605  15.1       .596            .010
# Bam Adebayo         C  23  MIA  64  2143  22.7       .626            .010
# LaMarcus Aldridge   C  35  TOT  26   674  15.7       .556            .270
#
#                     ftr orb_percent  ...     ows  dws    ws ws_per_48    \
# Player                               ...
# Precious Achiuwa   .482        11.5  ...     0.3  1.0   1.3      .085
# Jaylen Adams       .000         0.0  ...    -0.1  0.0  -0.1    -0.252
# Steven Adams       .438        14.4  ...     2.3  1.7   4.0      .119
# Bam Adebayo        .443         7.7  ...     5.6  3.2   8.8      .197
# LaMarcus Aldridge  .159         3.0  ...     0.5  0.6   1.1      .080
#
#                     obpm  dbpm    bpm  vorp
# Player
# Precious Achiuwa    -3.6  -0.5   -4.1  -0.4
# Jaylen Adams       -15.1  -4.6  -19.8  -0.1
# Steven Adams        -0.4   0.1   -0.3   0.7
# Bam Adebayo          2.9   2.0    4.9   3.7
# LaMarcus Aldridge   -0.2  -0.2   -0.3   0.3
#
# [5 rows x 27 columns]

# %%
df["ts_percent"] = pd.to_numeric(df["ts_percent"])
df["orb_percent"] = pd.to_numeric(df["orb_percent"])
df["drb_percent"] = pd.to_numeric(df["drb_percent"])
df["trb_percent"] = pd.to_numeric(df["trb_percent"])
df["ast_percent"] = pd.to_numeric(df["ast_percent"])
df["stl_percent"] = pd.to_numeric(df["stl_percent"])
df["blk_percent"] = pd.to_numeric(df["blk_percent"])
df["tov_percent"] = pd.to_numeric(df["tov_percent"])
df["usg_percent"] = pd.to_numeric(df["usg_percent"])
df.dtypes
# Out:
# pos                 object
# age                 object
# tm                  object
# g                   object
# mp                  object
# per                 object
# ts_percent         float64
# threepoint_attr     object
# ftr                 object
# orb_percent        float64
# drb_percent        float64
# trb_percent        float64
# ast_percent        float64
# stl_percent        float64
# blk_percent        float64
# tov_percent        float64
# usg_percent        float64
#                     object
# ows                 object
# dws                 object
# ws                  object
# ws_per_48           object
#                     object
# obpm                object
# dbpm                object
# bpm                 object
# vorp                object
# dtype: object

# %%
df.to_csv('advanced_stats_clean.csv')
